# %%
# Required modules

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
 # Load the data
# data = pd.read_csv("/content/drive/MyDrive/Appendix 2 EN Steels.csv")
data = pd.read_csv("Appendix 2 EN Steels.csv")
data.head()
# input parameters
X = data[['C', 'Si', 'Mn', 'P', 'Ni', 'Cr', 'Mo', 'Mn/S', 'CR', 'TT']]
# output parameters
Y = data[['YS', 'UTS', 'EL', 'RA', 'IS']]

# %%
# description of input data 

X.describe()
# Out:
#                 C          Si          Mn  ...        Mn/S          CR          TT
# count  140.000000  140.000000  140.000000  ...  140.000000  140.000000  140.000000
# mean     0.374929    0.264643    0.984143  ...   36.614286   24.850000  589.571429
# std      0.030429    0.045824    0.509700  ...   25.803236   27.747299   67.053843
# min      0.320000    0.190000    0.330000  ...    8.000000    3.000000  400.000000
# 25%      0.350000    0.250000    0.330000  ...    8.000000    7.000000  550.000000
# 50%      0.360000    0.250000    1.260000  ...   40.000000   12.000000  600.000000
# 75%      0.400000    0.300000    1.400000  ...   49.000000   38.000000  642.500000
# max      0.440000    0.370000    1.510000  ...   86.000000  118.000000  700.000000
#
# [8 rows x 10 columns]

# %%
# despcription of output data

Y.describe()
# Out:
#                 YS          UTS          EL          RA          IS
# count   140.000000   140.000000  140.000000  140.000000  140.000000
# mean    808.678571   933.300000   21.160714   56.342857   57.564286
# std     150.265150   127.840768    3.426656    6.460195   21.887288
# min     543.000000   707.000000   13.000000   31.000000   15.000000
# 25%     692.000000   839.000000   18.500000   52.500000   42.000000
# 50%     789.500000   912.000000   21.000000   57.000000   60.000000
# 75%     914.000000  1019.000000   23.625000   61.500000   75.000000
# max    1194.000000  1295.000000   29.000000   67.500000   94.000000

# %%
# sns.pairplot(data=data)

# %%
sns.set(style="whitegrid")
sns.lineplot(x="C", y="YS", ci=None, data=data, color='red')
sns.lineplot(x="C", y="UTS", ci=None, data=data, color='green')
sns.lineplot(x="C", y="EL", ci=None, data=data)
sns.lineplot(x="C", y="RA", ci=None, data=data)
sns.lineplot(x="C", y="IS", ci=None, data=data)

# %%
sns.lineplot(x="C", y="UTS", ci=None, data=data)

# %%
sns.lineplot(x="C", y="EL", ci=None, data=data)

# %%
sns.lineplot(x="C", y="IS", ci=None, data=data)

# %%
sns.barplot(x="C", y="IS", ci=None, data=data)

# %%
sns.lineplot(x="Si", y="YS", ci=None, data=data)
sns.lineplot(x="Si", y="UTS", ci=None, data=data)
sns.lineplot(x="Si", y="EL", ci=None, data=data)
sns.lineplot(x="Si", y="RA", ci=None, data=data)
sns.lineplot(x="Si", y="IS", ci=None, data=data)

# %%
sns.barplot(x="Si", y="YS", ci=None, data=data)
sns.barplot(x="Si", y="UTS", ci=None, data=data)
sns.barplot(x="Si", y="EL", ci=None, data=data)
sns.barplot(x="Si", y="RA", ci=None, data=data)
sns.barplot(x="Si", y="IS", ci=None, data=data)

# %%
sns.lineplot(x="Mn/S", y="YS", ci=None, data=data)
sns.lineplot(x="Mn/S", y="UTS", ci=None, data=data)
sns.lineplot(x="Mn/S", y="EL", ci=None, data=data)
sns.lineplot(x="Mn/S", y="RA", ci=None, data=data)
sns.lineplot(x="Mn/S", y="IS", ci=None, data=data)

# %%
sns.lineplot(x="Ni", y="YS", ci=None, data=data)
sns.lineplot(x="Ni", y="UTS", ci=None, data=data)
sns.lineplot(x="Ni", y="EL", ci=None, data=data)
sns.lineplot(x="Ni", y="RA", ci=None, data=data)
sns.lineplot(x="Ni", y="IS", ci=None, data=data)

# %%
sns.lineplot(x="Cr", y="YS", ci=None, data=data)
sns.lineplot(x="Cr", y="UTS", ci=None, data=data)
sns.lineplot(x="Cr", y="EL", ci=None, data=data)
sns.lineplot(x="Cr", y="RA", ci=None, data=data)
sns.lineplot(x="Cr", y="IS", ci=None, data=data)

# %%
sns.lineplot(x="CR", y="YS", ci=None, data=data)
sns.lineplot(x="CR", y="UTS", ci=None, data=data)
sns.lineplot(x="CR", y="EL", ci=None, data=data)
sns.lineplot(x="CR", y="RA", ci=None, data=data)
sns.lineplot(x="CR", y="IS", ci=None, data=data)

# %%
sns.lineplot(x="TT", y="YS", ci=None, data=data)
sns.lineplot(x="TT", y="UTS", ci=None, data=data)
sns.lineplot(x="TT", y="EL", ci=None, data=data)
sns.lineplot(x="TT", y="RA", ci=None, data=data)
sns.lineplot(x="TT", y="IS", ci=None, data=data)
